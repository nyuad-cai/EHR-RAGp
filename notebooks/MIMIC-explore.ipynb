# %%
import os
import pandas as pd

# %%
# (1)Patients, which contains static information about the patients, such as gender, date of birth, and date of death; 
# (2)Admissions, which holdsinformation about patient admissions to the hospital, including admissionand discharge times, as well as information related to the hospital stay; 
# (3)Icustays, which is specifically related to intensive care unit (ICU) stays,including the timings and type of ICU; 
# (4)Labevents, which containslaboratory test results for patients. We used the 200 most frequent testscovering 95% of tests completed; 
# (5)Prescriptions, which holds informationon medications prescribed to patients during their stay, with each drugconverted to ATC code33We converted GSN codes in MIMIC-IV to ATCcodes using conversion tables26;
# (6)Procedures which contains informationabout procedures performed on patients, codedusing ICD10-PCS codes; 
# (7)Diagnoses which contains diagnostic information, typically coded using ICD10-CM codes. We converted ICD9 to ICD10-CM if needed usingconversion table34;
# (8)Emar, which holds information related to the documentation and administration of medications to patients; 
# (9)Omr with information about measurements taken from a patient, such as blood pressure or BMI; 
# (10)Services with information about the clinical service under which a patient is managed during their hospital stay; 
# (11)drgcodesDRG codes which are a classification system used in the healthcare industry to categorize hospital cases into groups that are expected to have similarhospital resource use; 
# (12) SOFA, taken from the derived tables in MIMIC.

# %%
os.listdir('/scratch/fs999/shamoutlab/data/physionet.org/files/mimic-iv-1.0/icu/')
# Out:
# ['inputevents.csv',
#  'icustays.csv',
#  'd_items.csv',
#  'datetimeevents.csv',
#  'procedureevents.csv',
#  'outputevents.csv',
#  'chartevents.csv']

# %%
# patients = pd.read_csv('/scratch/fs999/shamoutlab/data/physionet.org/files/mimic-iv-1.0/core/patients.csv')
# admission = pd.read_csv('/scratch/fs999/shamoutlab/data/physionet.org/files/mimic-iv-1.0/core/admissions.csv')
# transfers = pd.read_csv('/scratch/fs999/shamoutlab/data/physionet.org/files/mimic-iv-1.0/core/transfers.csv')
chart = pd.read_csv()
# Out:
# /tmpdata/ipykernel_1092201/433388495.py:4: DtypeWarning: Columns (7,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   labs = pd.read_csv('/scratch/fs999/shamoutlab/data/physionet.org/files/mimic-iv-1.0/hosp/labevents.csv')

# %%
labs = pd.read_csv('/scratch/fs999/shamoutlab/data/physionet.org/files/mimic-iv-1.0/hosp/labevents.csv', low_memory=False)
procedures = pd.read_csv('/scratch/fs999/shamoutlab/data/physionet.org/files/mimic-iv-1.0/hosp/procedures_icd.csv', low_memory=False)

# %%
patients[patients.subject_id == 19999068]
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  dod
# 382275    19999068      M          63         2161       2011 - 2013  NaN

# %%
admission[admission.subject_id == 19999068]
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 518490    19999068  21606769  2161-08-24 04:10:00  2161-09-02 19:00:00
#
#        deathtime admission_type admission_location discharge_location  \
# 518490       NaN       EW EMER.     EMERGENCY ROOM   HOME HEALTH CARE
#
#        insurance language marital_status ethnicity            edregtime  \
# 518490  Medicare  ENGLISH       DIVORCED     WHITE  2161-08-24 03:14:00
#
#                   edouttime  hospital_expire_flag
# 518490  2161-08-24 05:26:00                     0

# %%
transfers[transfers.subject_id == 19999068]
# Out:
#          subject_id     hadm_id  transfer_id  eventtype  \
# 1936697    19999068  21606769.0     32284645  discharge
# 2035565    19999068  21606769.0     35130402         ED
# 2035711    19999068  21606769.0     37234188   transfer
# 2035773    19999068  21606769.0     38991029   transfer
# 2152710    19999068  21606769.0     30143796      admit
#
#                                                  careunit  \
# 1936697                                               NaN
# 2035565                              Emergency Department
# 2035711  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 2035773                                      Med/Surg/GYN
# 2152710  Medical/Surgical Intensive Care Unit (MICU/SICU)
#
#                       intime              outtime
# 1936697  2161-09-02 19:06:42                  NaN
# 2035565  2161-08-24 03:14:00  2161-08-24 05:26:00
# 2035711  2161-08-29 08:31:22  2161-08-30 23:48:04
# 2035773  2161-08-30 23:48:04  2161-09-02 19:06:42
# ...

# %%
labs[(labs.subject_id == 19999068) & (labs.hadm_id == 21606769.0)]
# Out:
#            labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 100791577    124058101    19999068  21606769.0     55530805   50802
# 100791578    124058102    19999068  21606769.0     55530805   50804
# 100791579    124058104    19999068  21606769.0     55530805   50818
# 100791580    124058105    19999068  21606769.0     55530805   50820
# 100791581    124058106    19999068  21606769.0     55530805   50821
# ...                ...         ...         ...          ...     ...
# 121664701    124058318    19999068  21606769.0      3980150   50920
# 121860974    124058165    19999068  21606769.0     74734534   51006
# 121860975    124058176    19999068  21606769.0      6336662   51006
# 121872788    124058147    19999068  21606769.0     53337656   51265
# 121897945    124058205    19999068  21606769.0     54198400   51266
#
#                      charttime            storetime value  valuenum valueuom  \
# ...

# %%
procedures[procedures.subject_id == 19999068]
# Out:
#         subject_id   hadm_id  seq_num   chartdate icd_code  icd_version
# 719508    19999068  21606769        2  2161-08-25     9671            9
# 719509    19999068  21606769        1  2161-08-25     9604            9
